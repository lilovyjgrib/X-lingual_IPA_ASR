# %%
import os
import librosa
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# Pfad zum TIMIT-Train-Ordner 
TIMIT_DIR = "/home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN"
 # //wsl.localhost/Ubuntu/home/aaron
 # Beispiel: "/Users/deinname/Daten/TIMIT/TRAIN"

# //wsl.localhost/Ubuntu/home/aaron/automated_speech_recognition/TIMIT/TIMIT

# Einstellungen für Audioverarbeitung
SAMPLE_RATE = 16000   # Einheitliche Samplingrate (16 kHz ist Standard für ASR)
N_MFCC = 13           # Anzahl der MFCC-Koeffizienten pro Frame

# Funktion zum Extrahieren von MFCC + Delta + Delta-Delta aus einer WAV-Datei

# this funcion uses the librosa package to extract the MFCC
def extract_mfcc(wav_path, sample_rate=SAMPLE_RATE, n_mfcc=N_MFCC):
    # load audio signal (resample if necessary)
    signal, sr = librosa.load(wav_path, sr=sample_rate)

    # extract mfcc with librosa
    mfcc = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=n_mfcc)

    # calculate first delta
    delta = librosa.feature.delta(mfcc)

    # calculate second delta
    delta2 = librosa.feature.delta(mfcc, order=2)

    # combine all features (static, 1-delat, 2-delta) to a 39 matrix (features per timeslot)
    combined = np.vstack([mfcc, delta, delta2])  # shape: [39, time]

    #transpone the matrix for [time_steps, 39]
    return combined.T

def load_transcript(txt_path):
    """
    Lädt die komplette Transkriptionszeile aus .TXT oder .WRD
    TIMIT .TXT-Dateien enthalten typischerweise eine Zeile wie:
      THIS IS A SAMPLE .
    """
    with open(txt_path, 'r', encoding='utf8') as f:
        # ganze Zeile, ohne Zeilenende
        return f.read().strip()

def load_phoneme_labels(phn_path):
    """
    Lädt die PHN-Datei und gibt eine einfache Liste von Phonemen zurück,
    z.B. ['sil', 'sh', 'iy', 'hv', ...]
    """
    phonemes = []
    with open(phn_path, 'r', encoding='utf8') as f:
        for line in f:
            _, _, label = line.strip().split()
            phonemes.append(label)
    return phonemes

# %%
def load_timit_data(timit_root):
    data = []  # Liste für alle Datenpunkte

    for root, _, files in os.walk(timit_root):
        print("Durchsuche Ordner:", root)
        print("Dateien:", files)
        for file in files:
            if file.lower().endswith(".wav"):
                wav_path = os.path.join(root, file)
                txt_path = wav_path.replace(".wav", ".TXT").replace(".WAV", ".TXT")
                phn_path = wav_path.replace(".wav", ".PHN").replace(".WAV", ".PHN")  

                if not os.path.exists(txt_path):
                    print("Keine Transkript-Datei gefunden für:", wav_path)
                    continue

                try:
                    mfcc_seq = extract_mfcc(wav_path)
                    # transcript = load_transcript(txt_path)
                    # tokens = list(transcript)
                    
                    phonemes = load_phoneme_labels(phn_path)
                    # phonemes_61 = load_phoneme_labels(phn_path)
                    # phonemes_39 = map_61_to_39(phonemes)

                    data.append({
                        "mfcc": mfcc_seq,
                        # "transcript": transcript,
                        # "tokens": tokens,
                        "phonemes": phonemes,
                        "path": wav_path, 
                        # "phonemes_61": phonemes_61,
                        # "phonemes_39": phonemes_39,
                    })

                except Exception as e:
                    print(f"Fehler bei {wav_path}: {e}")

    return data

# this function only loads the mfccs out of the timt data    
# def load_timit_data(timit_root):
#     data = []  

#     for root, _, files in os.walk(timit_root):
#         print("Durchsuche Ordner:", root)
#         print("Dateien:", files)
#         for file in files:
#             if file.lower().endswith(".wav"):
#                 wav_path = os.path.join(root, file)
                

#                 try:
#                     mfcc_seq = extract_mfcc(wav_path)
                   
#                     data.append({
#                         "mfcc": mfcc_seq,
#                     })

#                 except Exception as e:
#                     print(f"Fehler bei {wav_path}: {e}")

#     return data

# %%
dataset = load_timit_data(TIMIT_DIR)
# 🖨️ Beispielausgabe: Anzahl und Beispiel
print(f"Geladene Beispiele: {len(dataset)}")
# print("Beispieltranskript:", dataset[0]["transcript"])
print("Tokenliste:", dataset[0]["tokens"])
print("MFCC Shape:", dataset[0]["mfcc"].shape)
# Out:
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN
# Dateien: []
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6
# Dateien: []
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6/MEAL0
# Dateien: ['SX347.wav:Zone.Identifier', 'SI2177.wav:Zone.Identifier', 'SX107.wav:Zone.Identifier', 'SA1.PHN:Zone.Identifier', 'SI1547.WRD', 'SX347.PHN', 'SI2177.wav', 'SX287.PHN:Zone.Identifier', 'SI1547.wav:Zone.Identifier', 'SI917.PHN:Zone.Identifier', 'SI1547.PHN:Zone.Identifier', 'SI917.TXT', 'SX197.TXT', 'SX347.TXT', 'SX107.wav', 'SI917.wav', 'SX197.wav:Zone.Identifier', 'SI1547.WRD:Zone.Identifier', 'SX197.TXT:Zone.Identifier', 'SI2177.WRD:Zone.Identifier', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SI917.wav:Zone.Identifier', 'SX347.wav', 'SX377.WRD', 'SX377.TXT:Zone.Identifier', 'SX377.TXT', 'SX287.WRD', 'SX287.PHN', 'SX377.wav:Zone.Identifier', 'SA1.WRD', 'SX197.PHN', 'SA2.TXT', 'SX347.TXT:Zone.Identifier', 'SA1.TXT:Zone.Identifier', 'SI1547.TXT', 'SX107.PHN:Zone.Identifier', 'SI1547.TXT:Zone.Identifier', 'SX377.PHN', 'SX377.WRD:Zone.Identifier', 'SI2177.PHN', 'SI917.PHN', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX197.WRD:Zone.Identifier', 'SX197.wav', 'SI917.WRD:Zone.Identifier', 'SX287.wav', 'SX377.wav', 'SI1547.PHN', 'SI917.TXT:Zone.Identifier', 'SX377.PHN:Zone.Identifier', 'SX197.WRD', 'SA2.wav', 'SX107.WRD', 'SI1547.wav', 'SX347.PHN:Zone.Identifier', 'SA2.TXT:Zone.Identifier', 'SI2177.PHN:Zone.Identifier', 'SI2177.WRD', 'SX287.TXT', 'SA1.TXT', 'SX107.WRD:Zone.Identifier', 'SA2.WRD', 'SX197.PHN:Zone.Identifier', 'SA1.PHN', 'SX347.WRD:Zone.Identifier', 'SA2.WRD:Zone.Identifier', 'SX287.TXT:Zone.Identifier', 'SX107.TXT:Zone.Identifier', 'SI2177.TXT', 'SA1.wav:Zone.Identifier', 'SX107.TXT', 'SI917.WRD', 'SX107.PHN', 'SI2177.TXT:Zone.Identifier', 'SX287.WRD:Zone.Identifier', 'SX287.wav:Zone.Identifier', 'SA1.wav', 'SX347.WRD']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6/MTJU0
# Dateien: ['SX40.wav:Zone.Identifier', 'SI2020.wav', 'SX310.WRD:Zone.Identifier', 'SX310.PHN:Zone.Identifier', 'SA1.PHN:Zone.Identifier', 'SX220.WRD', 'SX130.wav', 'SX400.TXT', 'SI2020.PHN:Zone.Identifier', 'SX400.PHN', 'SX220.TXT', 'SX40.PHN', 'SI2269.WRD:Zone.Identifier', 'SI2269.TXT:Zone.Identifier', 'SI760.WRD:Zone.Identifier', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SX220.WRD:Zone.Identifier', 'SI760.PHN:Zone.Identifier', 'SI2020.wav:Zone.Identifier', 'SX220.PHN:Zone.Identifier', 'SX400.TXT:Zone.Identifier', 'SA1.WRD', 'SI760.wav', 'SA2.TXT', 'SX40.WRD', 'SX400.WRD:Zone.Identifier', 'SX310.wav', 'SI760.PHN', 'SX310.wav:Zone.Identifier', 'SI2269.TXT', 'SI2269.PHN:Zone.Identifier', 'SA1.TXT:Zone.Identifier', 'SX130.WRD', 'SI2020.TXT', 'SI2020.WRD', 'SI2269.PHN', 'SI2269.wav', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX400.WRD', 'SX310.TXT', 'SI760.TXT:Zone.Identifier', 'SX130.TXT:Zone.Identifier', 'SI760.WRD', 'SX130.wav:Zone.Identifier', 'SX40.wav', 'SI2269.wav:Zone.Identifier', 'SI2020.PHN', 'SX220.TXT:Zone.Identifier', 'SA2.wav', 'SX130.WRD:Zone.Identifier', 'SI760.TXT', 'SA2.TXT:Zone.Identifier', 'SX40.PHN:Zone.Identifier', 'SX220.PHN', 'SX40.TXT:Zone.Identifier', 'SX130.PHN', 'SI2020.TXT:Zone.Identifier', 'SA1.TXT', 'SX400.wav', 'SA2.WRD', 'SA1.PHN', 'SI2269.WRD', 'SA2.WRD:Zone.Identifier', 'SX40.TXT', 'SX310.WRD', 'SI760.wav:Zone.Identifier', 'SA1.wav:Zone.Identifier', 'SX310.PHN', 'SX130.PHN:Zone.Identifier', 'SX220.wav:Zone.Identifier', 'SX220.wav', 'SX40.WRD:Zone.Identifier', 'SX400.PHN:Zone.Identifier', 'SX310.TXT:Zone.Identifier', 'SX400.wav:Zone.Identifier', 'SX130.TXT', 'SA1.wav', 'SI2020.WRD:Zone.Identifier']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6/MEJL0
# Dateien: ['SI1592.wav', 'SX152.wav', 'SX332.TXT', 'SX62.wav', 'SA1.PHN:Zone.Identifier', 'SI1654.WRD', 'SI1654.TXT:Zone.Identifier', 'SI1654.TXT', 'SX62.WRD:Zone.Identifier', 'SX152.PHN:Zone.Identifier', 'SX152.WRD:Zone.Identifier', 'SX242.wav:Zone.Identifier', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SI962.wav:Zone.Identifier', 'SI1654.wav', 'SX422.PHN', 'SX332.PHN', 'SX62.PHN', 'SA1.WRD', 'SI1654.PHN:Zone.Identifier', 'SX152.WRD', 'SI962.WRD', 'SX422.TXT:Zone.Identifier', 'SA2.TXT', 'SX242.wav', 'SI1592.PHN', 'SX62.TXT', 'SX422.wav:Zone.Identifier', 'SA1.TXT:Zone.Identifier', 'SI1654.wav:Zone.Identifier', 'SX152.wav:Zone.Identifier', 'SI1654.PHN', 'SX152.PHN', 'SX62.WRD', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX422.TXT', 'SX422.wav', 'SX242.PHN:Zone.Identifier', 'SI962.PHN:Zone.Identifier', 'SX242.TXT', 'SA2.wav', 'SI962.TXT', 'SA2.TXT:Zone.Identifier', 'SX332.WRD:Zone.Identifier', 'SX332.wav:Zone.Identifier', 'SI1592.WRD:Zone.Identifier', 'SX422.WRD', 'SA1.TXT', 'SX152.TXT', 'SX242.WRD', 'SX242.TXT:Zone.Identifier', 'SA2.WRD', 'SX332.TXT:Zone.Identifier', 'SA1.PHN', 'SI962.TXT:Zone.Identifier', 'SX332.PHN:Zone.Identifier', 'SA2.WRD:Zone.Identifier', 'S
 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SI959.WRD', 'SX56.wav:Zone.Identifier', 'SI956.wav:Zone.Identifier', 'SX416.TXT', 'SX146.PHN', 'SI956.PHN:Zone.Identifier', 'SX146.TXT:Zone.Identifier', 'SA2.wav', 'SA2.TXT:Zone.Identifier', 'SI959.wav', 'SX326.wav', 'SX326.PHN', 'SX416.PHN:Zone.Identifier', 'SA1.TXT', 'SA2.WRD', 'SI956.WRD:Zone.Identifier', 'SA1.PHN', 'SI959.TXT:Zone.Identifier', 'SI959.TXT', 'SA2.WRD:Zone.Identifier', 'SX236.WRD:Zone.Identifier', 'SX416.WRD:Zone.Identifier', 'SX236.WRD', 'SI956.TXT', 'SX416.wav:Zone.Identifier', 'SX56.TXT', 'SX146.WRD:Zone.Identifier', 'SA1.wav:Zone.Identifier', 'SI956.WRD', 'SX56.TXT:Zone.Identifier', 'SI1586.PHN:Zone.Identifier', 'SX56.WRD:Zone.Identifier', 'SI959.PHN', 'SX236.wav:Zone.Identifier', 'SX416.wav', 'SX416.TXT:Zone.Identifier', 'SA1.wav']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6/MBMA1
# Dateien: ['SX324.WRD:Zone.Identifier', 'SX324.TXT:Zone.Identifier', 'SX144.PHN', 'SI954.WRD:Zone.Identifier', 'SA1.PHN:Zone.Identifier', 'SX234.TXT:Zone.Identifier', 'SX234.wav:Zone.Identifier', 'SX54.WRD:Zone.Identifier', 'SI2207.WRD:Zone.Identifier', 'SX234.TXT', 'SX144.PHN:Zone.Identifier', 'SI2214.WRD', 'SI2214.wav:Zone.Identifier', 'SI2214.PHN', 'SX144.WRD:Zone.Identifier', 'SI2214.wav', 'SI2214.WRD:Zone.Identifier', 'SX54.wav', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SX414.wav:Zone.Identifier', 'SX414.PHN', 'SX234.WRD:Zone.Identifier', 'SX234.WRD', 'SA1.WRD', 'SX54.TXT:Zone.Identifier', 'SI954.TXT:Zone.Identifier', 'SI2207.PHN', 'SI2207.PHN:Zone.Identifier', 'SX54.PHN', 'SA2.TXT', 'SI954.wav:Zone.Identifier', 'SI2207.WRD', 'SI2207.wav:Zone.Identifier', 'SX144.WRD', 'SX414.TXT:Zone.Identifier', 'SA1.TXT:Zone.Identifier', 'SX414.WRD:Zone.Identifier', 'SX414.wav', 'SX324.TXT', 'SX144.TXT', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX414.WRD', 'SI954.WRD', 'SI954.TXT', 'SX234.PHN:Zone.Identifier', 'SX324.PHN', 'SX234.wav', 'SI2214.TXT:Zone.Identifier', 'SX324.wav:Zone.Identifier', 'SA2.wav', 'SI2214.TXT', 'SA2.TXT:Zone.Identifier', 'SI2207.TXT:Zone.Identifier', 'SX54.TXT', 'SI2214.PHN:Zone.Identifier', 'SI954.PHN', 'SI2207.TXT', 'SA1.TXT', 'SX54.WRD', 'SA2.WRD', 'SA1.PHN', 'SX414.TXT', 'SX144.wav:Zone.Identifier', 'SA2.WRD:Zone.Identifier', 'SX54.PHN:Zone.Identifier', 'SX324.wav', 'SX144.TXT:Zone.Identifier', 'SA1.wav:Zone.Identifier', 'SI2207.wav', 'SI954.PHN:Zone.Identifier', 'SX234.PHN', 'SX324.PHN:Zone.Identifier', 'SX414.PHN:Zone.Identifier', 'SX324.WRD', 'SX54.wav:Zone.Identifier', 'SX144.wav', 'SA1.wav', 'SI954.wav']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6/MDRD0
# Dateien: ['SX212.TXT', 'SA1.PHN:Zone.Identifier', 'SX392.wav', 'SX212.wav', 'SX32.PHN', 'SI752.wav', 'SI752.PHN:Zone.Identifier', 'SX392.PHN:Zone.Identifier', 'SX32.wav:Zone.Identifier', 'SI2012.WRD:Zone.Identifier', 'SI2012.TXT:Zone.Identifier', 'SI752.WRD', 'SI752.wav:Zone.Identifier', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SX302.wav', 'SX392.wav:Zone.Identifier', 'SA1.WRD', 'SX212.TXT:Zone.Identifier', 'SX302.PHN:Zone.Identifier', 'SX32.WRD:Zone.Identifier', 'SA2.TXT', 'SX302.WRD', 'SX212.PHN:Zone.Identifier', 'SX32.wav', 'SX122.wav:Zone.Identifier', 'SI2012.PHN:Zone.Identifier', 'SA1.TXT:Zone.Identifier', 'SX302.TXT', 'SI2012.wav', 'SX212.PHN', 'SI2012.PHN', 'SX122.TXT:Zone.Identifier', 'SX302.TXT:Zone.Identifier', 'SX212.wav:Zone.Identifier', 'SI1382.PHN:Zone.Identifier', 'SX122.PHN', 'SX122.TXT', 'SX32.TXT:Zone.Identifier', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX302.WRD:Zone.Identifier', 'SX122.PHN:Zone.Identifier', 'SX392.PHN', 'SX32.WRD', 'SI1382.WRD:Zone.Identifier', 'SI752.PHN', 'SI1382.TXT', 'SI2012.WRD', 'SI1382.WRD', 'SA2.wav', 'SX122.WRD', 'SA2.TXT:Zone.Identifier', 'SI1382.TXT:Zone.Identifier', 'SX392.TXT', 'SI752.WRD:Zone.Identifier', 'SX212.WRD:Zone.Identifier', 'SX302.PHN', 'SX392.TXT:Zone.Identifier', 'SA1.TXT', 'SA2.WRD', 'SA1.PHN', 'SI1382.PHN', 'SX122.wav', 'SA2.WRD:Zone.Identifier', 'SX392.WRD', 'SX32.TXT', 'SA1.wav:Zone.Identifier', 'SX392.WRD:Zone.Identifier', 'SI2012.wav:Zone.Identifier', 'SX212.WRD', 'SI2012.TXT', 'SI1382.wav:Zone.Identifier', 'SI752.TXT:Zone.Identifier', 'SX32.PHN:Zone.Identifier', 'SI752.TXT', 'SX302.wav:Zone.Identifier', 'SX122.WRD:Zone.Identifier', 'SA1.wav', 'SI1382.wav']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6/MSDS0
# Dateien: ['SX267.TXT', 'SI2337.PHN:Zone.Identifier', 'SA1.PHN:Zone.Identifier', 'SX447.PHN', 'SX177.WRD:Zone.Identifier', 'SX447.TXT', 'SI2337.PHN', 'SI1707.TXT', 'SI1707.TXT:Zone.Identifier', 'SX357.wav', 'SX87.PHN:Zone.Identifier', 'SX267.wav:Zone.Identifier', 'SI1077.TXT', 'SX357.PHN', 'SI1077.PHN:Zone.Identifier', 'SI1077.PHN', 'SI1707.WRD', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SI2337.wav', 'SI2337.WRD', 'SI1077.TXT:Zone.Identifier', 'SA1.WRD', 'SI1707.PHN:Zone.Identifier', 'SX447.PHN:Zone.Identifier', 'SI1077.WRD', 'SI1707.WRD:Zone.Identifier', 'SX447.TXT:Zone.Identifier', 'SX267.wav', 'SA2.TXT', 'SX447.WRD', 'SX177.WRD', 'SX87.TXT:Zone.Identifier', 'SX267.WRD:Zone.Identifier', 'SI1707.PHN', 'SI2337.TXT:Zone.Identifier', 'SX177.TXT', 'SA1.TXT:Zone.Identifier', 'SI2337.TXT', 'SX267.WRD', 'SX267.TXT:Zone.Identifier', 'SX87.TXT', 'SI1707.wav:Zone.Identifier', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'S
Zone.Identifier', 'SA2.TXT:Zone.Identifier', 'SX322.TXT', 'SX52.TXT:Zone.Identifier', 'SI2212.wav:Zone.Identifier', 'SA1.TXT', 'SX142.WRD:Zone.Identifier', 'SX142.TXT', 'SA2.WRD', 'SA1.PHN', 'SI1582.TXT', 'SX232.wav', 'SA2.WRD:Zone.Identifier', 'SI2212.PHN', 'SX142.WRD', 'SX52.TXT', 'SA1.wav:Zone.Identifier', 'SX232.PHN', 'SX52.WRD', 'SI1964.WRD:Zone.Identifier', 'SX412.PHN:Zone.Identifier', 'SX52.PHN:Zone.Identifier', 'SI2212.TXT', 'SA1.wav', 'SI1964.PHN', 'SI1964.TXT:Zone.Identifier', 'SI2212.PHN:Zone.Identifier', 'SX322.WRD']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6/FHXS0
# Dateien: ['SX85.TXT', 'SI2302.WRD:Zone.Identifier', 'SI2302.TXT:Zone.Identifier', 'SA1.PHN:Zone.Identifier', 'SX355.PHN', 'SX265.PHN:Zone.Identifier', 'SX445.wav', 'SI2302.PHN', 'SX175.PHN:Zone.Identifier', 'SX355.TXT', 'SX175.wav', 'SI2302.TXT', 'SI2335.wav:Zone.Identifier', 'SI2302.wav:Zone.Identifier', 'SX265.PHN', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SX445.TXT:Zone.Identifier', 'SI1075.TXT', 'SI1075.PHN', 'SI2302.WRD', 'SX85.WRD', 'SA1.WRD', 'SI1075.WRD:Zone.Identifier', 'SX355.WRD:Zone.Identifier', 'SA2.TXT', 'SI2335.WRD:Zone.Identifier', 'SX445.wav:Zone.Identifier', 'SX265.TXT:Zone.Identifier', 'SX265.TXT', 'SA1.TXT:Zone.Identifier', 'SX175.TXT', 'SI2335.PHN:Zone.Identifier', 'SX265.WRD', 'SX175.WRD', 'SX445.TXT', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX355.PHN:Zone.Identifier', 'SX355.TXT:Zone.Identifier', 'SI2335.PHN', 'SX445.WRD', 'SX445.WRD:Zone.Identifier', 'SX85.wav', 'SA2.wav', 'SI2335.wav', 'SX175.TXT:Zone.Identifier', 'SX355.WRD', 'SX85.TXT:Zone.Identifier', 'SX445.PHN', 'SX85.PHN:Zone.Identifier', 'SA2.TXT:Zone.Identifier', 'SX175.WRD:Zone.Identifier', 'SI1075.TXT:Zone.Identifier', 'SI2335.TXT', 'SX355.wav:Zone.Identifier', 'SA1.TXT', 'SI1075.wav', 'SA2.WRD', 'SA1.PHN', 'SI2302.wav', 'SA2.WRD:Zone.Identifier', 'SI1075.PHN:Zone.Identifier', 'SI2302.PHN:Zone.Identifier', 'SX85.wav:Zone.Identifier', 'SA1.wav:Zone.Identifier', 'SX85.WRD:Zone.Identifier', 'SX265.wav:Zone.Identifier', 'SX355.wav', 'SX265.WRD:Zone.Identifier', 'SX85.PHN', 'SI2335.TXT:Zone.Identifier', 'SX175.wav:Zone.Identifier', 'SI1075.WRD', 'SX175.PHN', 'SX265.wav', 'SX445.PHN:Zone.Identifier', 'SI1075.wav:Zone.Identifier', 'SA1.wav', 'SI2335.WRD']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6/FRJB0
# Dateien: ['SX167.TXT:Zone.Identifier', 'SX347.wav:Zone.Identifier', 'SI1794.PHN', 'SX77.wav:Zone.Identifier', 'SX437.PHN:Zone.Identifier', 'SX77.TXT', 'SA1.PHN:Zone.Identifier', 'SX257.TXT', 'SI1427.PHN', 'SX347.PHN', 'SX437.wav:Zone.Identifier', 'SX257.WRD', 'SX167.WRD', 'SX77.wav', 'SI1794.WRD', 'SI1794.TXT', 'SX257.WRD:Zone.Identifier', 'SI1470.wav', 'SX437.TXT', 'SI1794.WRD:Zone.Identifier', 'SX347.TXT', 'SI1794.wav:Zone.Identifier', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'S
WRD', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SX417.PHN', 'SX57.WRD', 'SI1497.TXT', 'SA1.WRD', 'SX237.TXT:Zone.Identifier', 'SX417.WRD', 'SX417.wav:Zone.Identifier', 'SI867.TXT:Zone.Identifier', 'SA2.TXT', 'SI867.WRD', 'SX327.TXT', 'SX237.TXT', 'SA1.TXT:Zone.Identifier', 'SI867.PHN:Zone.Identifier', 'SI1497.PHN:Zone.Identifier', 'SX147.TXT', 'SI1497.WRD:Zone.Identifier', 'SX417.PHN:Zone.Identifier', 'SI2127.TXT:Zone.Identifier', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX237.PHN', 'SX147.WRD:Zone.Identifier', 'SX417.wav', 'SI1497.wav', 'SI2127.wav:Zone.Identifier', 'SA2.wav', 'SA2.TXT:Zone.Identifier', 'SI867.wav', 'SX147.wav', 'SX237.wav:Zone.Identifier', 'SI2127.PHN:Zone.Identifier', 'SA1.TXT', 'SI1497.PHN', 'SA2.WRD', 'SA1.PHN', 'SI867.WRD:Zone.Identifier', 'SX417.TXT', 'SA2.WRD:Zone.Identifier', 'SX237.WRD:Zone.Identifier', 'SX237.PHN:Zone.Identifier', 'SX417.TXT:Zone.Identifier', 'SA1.wav:Zone.Identifier', 'SX57.TXT', 'SX327.wav', 'SI2127.WRD:Zone.Identifier', 'SX327.wav:Zone.Identifier', 'SI1497.WRD', 'SX327.WRD:Zone.Identifier', 'SX147.PHN:Zone.Identifier', 'SX57.PHN:Zone.Identifier', 'SI867.PHN', 'SI867.wav:Zone.Identifier', 'SX327.PHN:Zone.Identifier', 'SX57.WRD:Zone.Identifier', 'SA1.wav', 'SX57.wav:Zone.Identifier', 'SX57.TXT:Zone.Identifier', 'SX57.PHN']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR1/MWAD0
# Dateien: ['SX342.PHN', 'SX162.PHN:Zone.Identifier', 'SX162.TXT', 'SX162.PHN', 'SA1.PHN:Zone.Identifier', 'SX162.WRD', 'SX342.wav:Zone.Identifier', 'SI2322.WRD', 'SI2322.WRD:Zone.Identifier', 'SX162.WRD:Zone.Identifier', 'SI2322.wav:Zone.Identifier', 'SI1062.wav:Zone.Identifier', 'SI1749.wav', 'SX162.wav:Zone.Identifier', 'SI1749.WRD:Zone.Identifier', 'SX432.TXT:Zone.Identifier', 'SI1749.WRD', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SX342.WRD:Zone.Identifier', 'SX432.wav:Zone.Identifier', 'SX252.PHN:Zone.Identifier', 'SX72.PHN', 'SI2322.PHN', 'SA1.WRD', 'SX72.WRD', 'SX342.TXT:Zone.Identifier', 'SA2.TXT', 'SX432.PHN', 'SX252.wav:Zone.Identifier', 'SX72.wav:Zone.Identifier', 'SX432.wav', 'SI1749.TXT', 'SA1.TXT:Zone.Identifier', 'SX342.WRD', 'SI1749.PHN:Zone.Identifier', 'SI1062.TXT', 'SX162.TXT:Zone.Identifier', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX252.WRD', 'SX72.TXT:Zone.Identifier', 'SX432.WRD:Zone.Identifier', 'SX342.PHN:Zone.Identifier', 'SX342.wav', 'SX72.WRD:Zone.Identifier', 'SI1062.wav', 'SA2.wav', 'SA2.TXT:Zone.Identifier', 'SI1062.WRD:Zone.Identifier', 'SA1.TXT', 'SI1062.TXT:Zone.Identifier', 'SI1749.wav:Zone.Identifier', 'SA2.WRD', 'SA1.PHN', 'SX252.PHN', 'SX72.PHN:Zone.Identifier', 'SX72.TXT', 'SI2322.PHN:Zone.Identifier', 'SA2.WRD:Zone.Identifier', 'SI2322.wav', 'SI1062.PHN', 'SI1749.PHN', 'SI2322.TXT:Zone.Identifier', 'SX252.WRD:Zone.Identifier', 'SX432.WRD', 'SA1.wav:Zone.Identifier', 'SX72.wav', 'SI1062.WRD', 'SI1749.TXT:Zone.Identifier', 'SI1062.PHN:Zone.Identifier', 'SX432.TXT', 'SX432.PHN:Zone.Identifier', 'SX342.TXT', 'SX252.TXT:Zone.Identifier', 'SX162.wav', 'SX252.wav', 'SX252.TXT', 'SI2322.TXT', 'SA1.wav']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR1/MKLS0
# Dateien: ['SI1437.WRD:Zone.Identifier', 'SX267.TXT', 'SA1.PHN:Zone.Identifier', 'SX447.PHN', 'SX177.WRD:Zone.Identifier', 'SX447.TXT', 'SX357.wav', 'SX87.PHN:Zone.Identifier', 'SI2067.TXT:Zone.Identifier', 'SX267.wav:Zone.Identifier', 'SX357.PHN', 'SI2067.wav:Zone.Identifier', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SI2067.WRD:Zone.Identifier', 'SI1437.PHN', 'SA1.WRD', 'SX447.PHN:Zone.Identifier', 'SI2067.PHN:Zone.Identifier', 'SI2067.WRD', 'SX447.TXT:Zone.Identifier', 'SI1533.WRD:Zone.Identifier', 'SX267.wav', 'SA2.TXT', 'SX447.WRD', 'SX177.WRD', 'SX87.TXT:Zone.Identifier', 'SX267.WRD:Zone.Identifier', 'SX177.TXT', 'SI1437.WRD', 'SA1.TXT:Zone.Identifier', 'SX267.WRD', 'SX267.TXT:Zone.Identifier', 'SX87.TXT', 'SI2067.TXT', 'SI1533.WRD', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX87.wav:Zone.Identifier', 'SI1437.TXT:Zone.Identifier', 'SX177.wav:Zone.Identifier', 'SI1533.TXT', 'SX447.WRD:Zone.Identifier', 'SI1533.wav', 'SX177.TXT:Zone.Identifier', 'SX177.PHN', 'SA2.wav', 'SX357.TXT', 'SX87.WRD:Zone.Identifier', 'SA2.TXT:Zone.Identifier', 'SX177.PHN:Zone.Identifier', 'SX357.PHN:Zone.Identifier', 'SI1533.PHN', 'SX177.wav', 'SX267.PHN:Zone.Identifier', 'SX447.wav:Zone.Identifier', 'SX87.WRD', 'SI1533.TXT:Zone.Identifier', 'SA1.TXT', 'SI1533.PHN:Zone.Identifier', 'SX87.wav', 'SX357.WRD', 'SA2.WRD', 'SX447.wav', 'SA1.PHN', 'SX357.TXT:Zone.Identifier', 'SI1437.TXT', 'SA2.WRD:Zone.Identifier', 'SI1437.wav:Zone.Identifier', 'SX267.PHN', 'SA1.wav:Zone.Identifier', 'SI1437.wav', 'SX87.PHN', 'SX357.WRD:Zone.Identifier', 'SI2067.PHN', 'SI1533.wav:Zone.Identifier', 'SI2067.wav', 'SI1437.PHN:Zone.Identifier', 'SA1.wav', 'SX357.wav:Zone.Identifier']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR1/FJSP0
# Dateien: ['SI1434.TXT:Zone.Identifier', 'SI1763.WRD', 'SI804.WRD:Zone.Identifier', 'SX84.PHN:Zone.Identifier', 'SX354.TXT:Zone.Identifier', 'SA1.PHN:Zone.Identifier', 'SX264.WRD', 'SI1434.wav', 'SX84.WRD', 'SI1434.WRD', 'SI1763.TXT', 'SI1434.PHN', 'SX174.WRD:Zone.Identifier', 'SI1434.WRD:Zone.Identifier', 'SX84.wav:Zone.Identifier', 'SX264.wav', 'SI804.TXT:Zone.Identifier', 'SX174.WRD', 'SI1763.PHN:Zone.Identifier', 'SX264.PHN', 'SA2.PHN:Zone.Identifier', 'SA1.WRD:Zone.Identifier', 'SX444.WRD', 'SX354.PHN:Zone.Identifier', 'SX444.PHN', 'SI1763.wav', 'SX84.wav', 'SI804.PHN:Zone.Identifier', 'SX264.WRD:Zone.Identifier', 'SA1.WRD', 'SX444.wav:Zone.Identifier', 'SA2.TXT', 'SX264.TXT:Zone.Identifier', 'SX174.PHN:Zone.Identifier', 'SI804.PHN', 'SI1434.TXT', 'SI1763.WRD:Zone.Identifier', 'SI804.TXT', 'SI1434.PHN:Zone.Identifier', 'SX84.TXT', 'SA1.TXT:Zone.Identifier', 'SX264.PHN:Zone.Identifier', 'SX174.TXT:Zone.Identifier', 'SX174.wav', 'SX174.TXT', 'SX84.TXT:Zone.Identifier', 'SX84.PHN', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX444.TXT:Zone.Identifier', 'SX174.wav:Zone.Identifier', 'SX174.PHN', 'SX444.WRD:Zone.Identifier', 'SA2.wav', 'SA2.TXT:Zone.Identifier', 'SI1763.wav:Zone.Identifier', 'SA1.TXT', 'SX84.WRD:Zone.Identifier', 'SA2.WRD', 'SA1.PHN', 'SX444.TXT', 'SI804.WRD', 'SA2.WRD:Zone.Identifier', 'SI1434.wav:Zone.Identifier', 'SA1.wav:Zone.Identifier', 'SX354.TXT', 'SI1763.TXT:Zone.Identifier', 'SX354.wav', 'SX444.PHN:Zone.Identifier', 'SX354.WRD', 'SX264.TXT', 'SX354.WRD:Zone.Identifier', 'SI804.wav:Zone.Identifier', 'SX354.wav:Zone.Identifier', 'SX264.wav:Zone.Identifier', 'SI1763.PHN', 'SX354.PHN', 'SI804.wav', 'SX444.wav', 'SA1.wav']
# Durchsuche Ordner: /home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR1/MDAC0
# Dateien: ['SX361.wav:Zone.Identifier', 'SX91.wav', 'SX361.TXT:Zone.Identifier', 'SI1837.TXT', 'SA1.PHN:Zone.Identifier', 'SX271.PHN', 'SX91.PHN', 'SX271.TXT', 'SX361.TXT', 'SI631.PHN:Zone.Identifier', 'SI1837.wav:Zone.Identifier', 'SX91.WRD', 'SX271.WRD', 'SX91.PHN:Zone.Identifier', 'SX451.WRD:Zone.Identifier', 'SX271.wav:Zone.Identifier', 'SX361.PHN:Zone.Identifier', 'SX271.TXT:Zone.Identifier', 'SI631.WRD:Zone.Identifier', 'SI1837.TXT:Zone.Identifier', 'SA2.PHN:Zone.Identifier', 'SX181.PHN', 'SA1.WRD:Zone.Identifier', 'SX181.TXT:Zone.Identifier', 'SI631.wav:Zone.Identifier', 'SA1.WRD', 'SX91.TXT', 'SA2.TXT', 'SI1837.PHN', 'SX361.PHN', 'SX271.wav', 'SX271.WRD:Zone.Identifier', 'SI631.WRD', 'SA1.TXT:Zone.Identifier', 'SX181.WRD:Zone.Identifier', 'SX451.PHN', 'SI1261.wav:Zone.Identifier', 'SI1261.PHN:Zone.Identifier', 'SX181.wav:Zone.Identifier', 'SX91.WRD:Zone.Identifier', 'SI1261.TXT', 'SX451.PHN:Zone.Identifier', 'SA2.wav:Zone.Identifier', 'SA2.PHN', 'SX91.TXT:Zone.Identifier', 'SX181.wav', 'SI1261.WRD:Zone.Identifier', 'SI631.wav', 'SX181.TXT', 'SI631.TXT', 'SA2.wav', 'SX451.TXT:Zone.Identifier', 'SI1261.PHN', 'SA2.TXT:Zone.Identifier', 'SX451.WRD', 'SX451.TXT', 'SI631.PHN', 'SI1837.wav', 'SX361.WRD:Zone.Identifier', 'SA1.TXT', 'SA2.WRD', 'SA1.PHN', 'SX181.PHN:Zone.Identifier', 'SX451.wav:Zone.Identifier', 'SA2.WRD:Zone.Identifier', 'SI1837.WRD', 'SI1261.TXT:Zone.Identifier', 'SI1261.WRD', 'SA1.wav:Zone.Identifier', 'SI1837.WRD:Zone.Identifier', 'SX271.PHN:Zone.Identifier', 'SX361.WRD', 'SX451.wav', 'SI631.TXT:Zone.Identifier', 'SX181.WRD', 'SX91.wav:Zone.Identifier', 'SI1261.wav', 'SI1837.PHN:Zone.Identifier', 'SA1.wav', 'SX361.wav']
# Geladene Beispiele: 4620
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 5
#       3 print(f"Geladene Beispiele: {len(dataset)}")
#       4 # print("Beispieltranskript:", dataset[0]["transcript"])
# ----> 5 print("Tokenliste:", dataset[0]["tokens"])
#       6 print("MFCC Shape:", dataset[0]["mfcc"].shape)
#
# KeyError: 'tokens'

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence


# # === MFCCs save for PyTorch ===
def save_data(data, output_path):
    torch.save(data, output_path)
    print(f"Gespeichert unter: {output_path}")

# # === PyTorch Dataset ===
class TIMITMFCCDataset(Dataset):
    def __init__(self, data_path):
        self.data = torch.load(data_path)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        mfcc = self.data[idx]["mfcc"]
        return torch.tensor(mfcc, dtype=torch.float32)

# === Collate-Funktion für Padding ===
def pad_collate(batch):
    return pad_sequence(batch, batch_first=True)  # => [batch, max_len, 39]#

# %%
# update the location!!
save_data(dataset, "/home/aaron/automated_speech_recognition/data1/timit_mfcc_data.pt")
# Out:
# Gespeichert unter: /home/aaron/automated_speech_recognition/data1/timit_mfcc_data.pt

# %%
# Lade die Datei
data = torch.load("/home/aaron/automated_speech_recognition/data1/timit_mfcc_data.pt", weights_only=False)

# analysing the data
print(type(data))            # z.B. <class 'list'>
print(len(data))             # z.B. Anzahl der Beispiele
print(type(data[0]))         # z.B. <class 'dict'>
print(data[0].keys())        # z.B. dict_keys(['mfcc'])
print(data[0]['mfcc'].shape) # z.B. torch.Size([123, 39])
# Out:
# <class 'list'>
# 4620
# <class 'dict'>
# dict_keys(['mfcc', 'phonemes', 'path'])
# (78, 39)

# %%
data[1]
# Out:
# {'mfcc': array([[-7.43217407e+02,  5.11423645e+01,  3.72760468e+01, ...,
#           4.05487746e-01, -1.76596975e+00,  4.28943634e-01],
#         [-7.14529724e+02,  3.65434113e+01,  3.51341553e+01, ...,
#           4.05487746e-01, -1.76596975e+00,  4.28943634e-01],
#         [-7.24818176e+02,  5.14628887e+00,  1.87460880e+01, ...,
#           4.05487746e-01, -1.76596975e+00,  4.28943634e-01],
#         ...,
#         [-5.98549316e+02,  8.02442474e+01,  7.14992046e+00, ...,
#          -8.71393144e-01, -3.89135652e-03,  1.12605953e+00],
#         [-6.42915771e+02,  6.33814735e+01,  1.24211855e+01, ...,
#          -8.71393144e-01, -3.89135652e-03,  1.12605953e+00],
#         [-6.82504211e+02,  6.10673752e+01,  2.24931469e+01, ...,
#          -8.71393144e-01, -3.89135652e-03,  1.12605953e+00]],
#        shape=(65, 39), dtype=float32),
#  'phonemes': ['h#',
#   'b',
#   'er',
#   'th',
#   'dcl',
#   'd',
#   'ey',
#   'pcl',
#   'p',
#   'aa',
#   'r',
#   'dx',
#   'iy',
#   'z',
#   'hh',
#   'eh',
#   'v',
#   'kcl',
#   'k',
#   'ah',
#   'pcl',
#   'k',
#   'ey',
#   'kcl',
#   'k',
#   's',
#   'ix',
#   'nx',
#   'ay',
#   's',
#   'kcl',
#   'k',
#   'r',
#   'iy',
#   'm',
#   'h#'],
#  'path': '/home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR6/MEAL0/SX107.wav'}

# %%
# read a phonme data; data analyseses
def read_phonemes(phn_path):
    phonemes = []
    with open(phn_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) == 3:
                _, _, phoneme = parts
                phonemes.append(phoneme)
    return phonemes

read_phonemes("/home/aaron/automated_speech_recognition/TIMIT/TIMIT/TRAIN/DR1/FCJF0/SA1.PHN")
# Out:
# ['h#',
#  'sh',
#  'ix',
#  'hv',
#  'eh',
#  'dcl',
#  'jh',
#  'ih',
#  'dcl',
#  'd',
#  'ah',
#  'kcl',
#  'k',
#  's',
#  'ux',
#  'q',
#  'en',
#  'gcl',
#  'g',
#  'r',
#  'ix',
#  's',
#  'ix',
#  'w',
#  'ao',
#  'sh',
#  'epi',
#  'w',
#  'ao',
#  'dx',
#  'axr',
#  'ao',
#  'l',
#  'y',
#  'ih',
#  'axr',
#  'h#']

# %%
# Funktion zur Textnormalisierung (vereinfachte Variante)
def normalize_text(text):
    # In Kleinbuchstaben umwandeln
    text = text.lower()

    # Sonderzeichen entfernen (nur Buchstaben, Zahlen, Leerzeichen bleiben erhalten)
    text = ''.join(c for c in text if c.isalnum() or c.isspace())

    # Überflüssige Leerzeichen am Anfang/Ende entfernen
    return text.strip()

# Funktion zum Laden der Transkription aus der zugehörigen .TXT-Datei
def load_transcript(txt_path):
    with open(txt_path, 'r') as f:
        # Jede .TXT-Datei enthält eine Zeile wie: 0 3400 she had your dark suit
        # Wir holen nur den tatsächlichen Text (nach dem zweiten Leerzeichen)
        return normalize_text(f.readline().split(' ', 2)[-1])

# %%
# Out:
# {'mfcc': array([[-7.43217407e+02,  5.11423645e+01,  3.72760468e+01, ...,
#           4.05487746e-01, -1.76596975e+00,  4.28943634e-01],
#         [-7.14529724e+02,  3.65434113e+01,  3.51341553e+01, ...,
#           4.05487746e-01, -1.76596975e+00,  4.28943634e-01],
#         [-7.24818176e+02,  5.14628887e+00,  1.87460880e+01, ...,
#           4.05487746e-01, -1.76596975e+00,  4.28943634e-01],
#         ...,
#         [-5.98549316e+02,  8.02442474e+01,  7.14992046e+00, ...,
#          -8.71393144e-01, -3.89135652e-03,  1.12605953e+00],
#         [-6.42915771e+02,  6.33814735e+01,  1.24211855e+01, ...,
#          -8.71393144e-01, -3.89135652e-03,  1.12605953e+00],
#         [-6.82504211e+02,  6.10673752e+01,  2.24931469e+01, ...,
#          -8.71393144e-01, -3.89135652e-03,  1.12605953e+00]],
#        shape=(65, 39), dtype=float32)}
